# %%
# !pip install pandas==1.3.5

# %% [markdown]
# # Load s3 file

# %%
import io
import boto3
import configparser

import numpy as np
import pandas as pd

def read_csv_from_s3(section_name, bucket_name, file_path, ):
    
    parser = configparser.ConfigParser()
    parser.read('./config.ini')
    access_key = parser.get(section_name, "access_key")
    secret_key = parser.get(section_name, "secret_key")
    
    s3 = boto3.client('s3',
                      aws_access_key_id=access_key, 
                      aws_secret_access_key=secret_key)
    print("Get object")
    obj = s3.get_object(Bucket=bucket_name, Key=file_path)

    print("Read csv")
    df = pd.read_csv( io.BytesIO( obj["Body"].read() ) )
    
    print("Completed")
    print("Data size:", df.shape)

    return df

# %% [markdown]
# This notebook was tested on a ml.m5.large notebook instance

# %%
section_name = "aws_boto_credentials"
bucket_name = "s3-test-ev"
file_path = "raw/vehicles.csv"

df = read_csv_from_s3(section_name, bucket_name, file_path)
# Out:
# Get object
# Read csv
# Completed
# Data size: (426880, 26)

# %% [markdown]
# # EDA - used cars

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB

# %%
cols_drop = []

# %% [markdown]
# ### 1. id

# %% [markdown]
# * consists of unique values (exclude to train)

# %% [markdown]
# ### 2. url

# %% [markdown]
# * consists of unique values (drop)

# %%
cols_drop.append("url")

# %% [markdown]
# ### 3. region

# %%
col = "region"
df[col].value_counts()[:5]
# Out:
# columbus                   3608
# jacksonville               3562
# spokane / coeur d'alene    2988
# eugene                     2985
# fresno / madera            2983
# Name: region, dtype: int64

# %%
display(df[col].value_counts().sort_index()[:20])
display(df[col].value_counts().sort_index()[-20:])
# Out:
# SF bay area             2936
# abilene                  235
# akron / canton          2211
# albany                  2537
# albuquerque             2952
# altoona-johnstown        364
# amarillo                 564
# ames                     194
# anchorage / mat-su      2742
# ann arbor               1085
# annapolis                285
# appleton-oshkosh-FDL    1261
# asheville               1423
# ashtabula                270
# athens                   607
# atlanta                 2965
# auburn                   142
# augusta                  480
# austin                  2969
# bakersfield             2528
# Name: region, dtype: int64
# west virginia (old)          8
# western IL                  63
# western KY                 212
# western maryland           285
# western massachusetts     2039
# western slope             1188
# wichita                   1694
# wichita falls              589
# williamsport               362
# wilmington                 975
# winchester                 672
# winston-salem             1027
# worcester / central MA    1914
# wyoming                    610
# yakima                    1704
# york                       777
# youngstown                 664
# yuba-sutter               1747
# yuma                       335
# zanesville / cambridge     313
# Name: region, dtype: int64

# %% [markdown]
# #### 3.1. region with long, lat

# %%
# check duplicated region name
region_grp_loc = df.groupby(["long", "lat"])["region"].agg([set]).reset_index()
region_grp_loc["region_cnt"] = region_grp_loc["set"].apply(lambda x: len(x))
region_grp_loc.sort_values(['region_cnt'], ascending=False)
# Out:
#              long        lat  \
# 20965  -95.785580  37.132840
# 1479  -123.030322  44.927304
# 21825  -95.268600  30.123700
# 45797  -80.241520  25.827103
# 11663 -112.058490  33.681077
# ...           ...        ...
# 21192  -95.622363  36.303847
# 21193  -95.622339  36.303799
# 21194  -95.621331  30.217831
# 21195  -95.619987  37.059508
# 60210  173.885502 -67.144243
#
#                                                      set  region_cnt
# 20965  {ann arbor, kenai peninsula, space coast, denv...          75
# 1479   {long island, chico, yuma, lafayette, harrisbu...          55
# 21825  {roswell / carlsbad, lafayette, del rio / eagl...          43
# 45797  {ann arbor, baton rouge, kenosha-racine, logan...          41
# 11663  {denver, bakersfield, phoenix, buffalo, seattl...          40
# ...                                                  ...         ...
# 21192                                            {tulsa}           1
# 21193                                     {fayetteville}           1
# 21194                                          {houston}           1
# 21195                                           {boston}           1
# 60210                               {anchorage / mat-su}           1
#
# [60211 rows x 4 columns]

# %%
idx_multi = region_grp_loc.region_cnt > 1
region_grp_loc[idx_multi]["set"].drop_duplicates()
# Out:
# 67                                       {phoenix, hawaii}
# 416                  {kenai peninsula, anchorage / mat-su}
# 493                        {fairbanks, anchorage / mat-su}
# 495      {kenai peninsula, fairbanks, southeast alaska,...
# 505                   {anchorage / mat-su, seattle-tacoma}
#                                ...
# 59868                   {cape cod / islands, rhode island}
# 59901    {worcester / central MA, new hampshire, maine,...
# 59936                    {cape cod / islands, south coast}
# 59948    {cape cod / islands, south coast, rhode island...
# 60203    {raleigh / durham / CH, greenville / upstate, ...
# Name: set, Length: 3125, dtype: object

# %%
df.groupby(["long", "lat", "region"])["id"].count().reset_index()
# Out:
#              long        lat              region  id
# 0     -159.827728  21.954580              hawaii   1
# 1     -159.719900  21.973500              hawaii   2
# 2     -159.707445  21.908386              hawaii   1
# 3     -159.590001  22.033605              hawaii   3
# 4     -159.583200  21.907400              hawaii   1
# ...           ...        ...                 ...  ..
# 71845   94.163200  45.557900            st cloud  12
# 71846  129.287109  40.564085        south jersey   1
# 71847  139.691700  35.689500            stockton   1
# 71848  167.629911  77.860640                erie   3
# 71849  173.885502 -67.144243  anchorage / mat-su   1
#
# [71850 rows x 4 columns]

# %% [markdown]
# ### 4. region_url

# %% [markdown]
# * almost values have 1:1 correspondence with region (drop)

# %%
cols_drop.extend(["region_url", "region_url_parse"])

# %%
df["region_url"].value_counts()
# Out:
# https://spokane.craigslist.org     2988
# https://eugene.craigslist.org      2985
# https://fresno.craigslist.org      2983
# https://orlando.craigslist.org     2983
# https://omaha.craigslist.org       2982
#                                    ...
# https://nesd.craigslist.org          34
# https://bigbend.craigslist.org       30
# https://meridian.craigslist.org      28
# https://natchez.craigslist.org       14
# https://wv.craigslist.org             8
# Name: region_url, Length: 413, dtype: int64

# %%
df["region_url_parse"] = df["region_url"].apply(lambda x: x.split(".")[0][8:])
df["region_url_parse"].value_counts()
# Out:
# spokane     2988
# eugene      2985
# fresno      2983
# orlando     2983
# omaha       2982
#             ...
# nesd          34
# bigbend       30
# meridian      28
# natchez       14
# wv             8
# Name: region_url_parse, Length: 413, dtype: int64

# %% [markdown]
# #### 1.4.1. region_url with region

# %%
df[["region", "region_url_parse"]]
# Out:
#                         region region_url_parse
# 0                     prescott         prescott
# 1                 fayetteville            fayar
# 2                 florida keys             keys
# 3       worcester / central MA        worcester
# 4                   greensboro       greensboro
# ...                        ...              ...
# 426875                 wyoming          wyoming
# 426876                 wyoming          wyoming
# 426877                 wyoming          wyoming
# 426878                 wyoming          wyoming
# 426879                 wyoming          wyoming
#
# [426880 rows x 2 columns]

# %%
df[["region", "region_url_parse"]].nunique()
# Out:
# region              404
# region_url_parse    413
# dtype: int64

# %%
region_grp_url = df.groupby(["region"])["region_url_parse"].agg([set]).reset_index()
region_grp_url["url_cnt"] = region_grp_url["set"].apply(lambda x: len(x))
print(region_grp_url.shape)
region_grp_url.sort_values(["url_cnt"], ascending=False).head(15)
# Out:
# (404, 3)
#            region                           set  url_cnt
# 157       jackson     {jxn, jackson, jacksontn}        3
# 288      richmond        {richmondin, richmond}        2
# 222        monroe            {monroemi, monroe}        2
# 3          albany            {albany, albanyga}        2
# 341   springfield  {springfield, springfieldil}        2
# 105  fayetteville         {fayar, fayetteville}        2
# 51     charleston    {charleston, charlestonwv}        2
# 158  jacksonville        {onslow, jacksonville}        2
# 290     rochester              {rmn, rochester}        2
# 67       columbus        {columbusga, columbus}        2
# 14         athens        {athensga, athensohio}        2
# 268  philadelphia                {philadelphia}        1
# 267        peoria                      {peoria}        1
# 0     SF bay area                       {sfbay}        1
# 269       phoenix                     {phoenix}        1

# %%
url_grp_region = df.groupby(["region_url_parse"])["region"].agg([set]).reset_index()
url_grp_region["url_cnt"] = url_grp_region["set"].apply(lambda x: len(x))
url_grp_region.sort_values(["url_cnt"], ascending=False).head(5)
# Out:
#     region_url_parse                             set  url_cnt
# 355          stlouis        {st louis, st louis, MO}        2
# 121        fortsmith    {fort smith, fort smith, AR}        2
# 171       kansascity  {kansas city, MO, kansas city}        2
# 0            abilene                       {abilene}        1
# 273      palmsprings                  {palm springs}        1

# %%
url_grp_region.loc[171, "set"]
# Out:
# {'kansas city', 'kansas city, MO'}

# %% [markdown]
# grouping region
# * ('st louis, MO', 'st louis') -> stlouis
# * ('fort smith', 'fort smith, AR') -> fortsmith
# * ('kansas city', 'kansas city, MO') -> kansascity

# %% [markdown]
# ### 5. price (target)

# %%
df["price"].describe()
# Out:
# count    4.268800e+05
# mean     7.519903e+04
# std      1.218228e+07
# min      0.000000e+00
# 25%      5.900000e+03
# 50%      1.395000e+04
# 75%      2.648575e+04
# max      3.736929e+09
# Name: price, dtype: float64

# %% [markdown]
# #### 5.1. outliers

# %%
np.quantile(df["price"], [0.05, 0.1, 0.8, 0.9, 0.95, 0.99])
# Out:
# array([    0.,   500., 29777., 37590., 44500., 66995.])

# %%
fig, ax = plt.subplots(figsize=(8, 4))
df["price"].hist(bins=np.arange(0, 1e5, 1e3), edgecolor="k", ax=ax)
plt.show()

# %%
cols_main = [x for x in df.columns if x not in cols_drop+["id", "image_url", "long", "lat", "description"]]

# %%
df[df.price.apply(lambda x: True if len(str(x))==10 else False)][cols_main]
# Out:
#                  region       price    year   manufacturer  \
# 29386   humboldt county  1111111111  1999.0           ford
# 37409           modesto  1111111111  2020.0           jeep
# 37410           modesto  3009548743  2021.0      chevrolet
# 91576          delaware  3024942282  2000.0  mercedes-benz
# 153082     indianapolis  1234567890  2006.0          volvo
# 184704        frederick  1410065407  1989.0           jeep
# 257840     south jersey  3024942282  2000.0  mercedes-benz
# 318592           eugene  3736928711  2007.0         toyota
# 356716        knoxville  3736928711  1999.0         toyota
#
#                          model  condition    cylinders    fuel  odometer  \
# 29386   f350 super duty lariat       good  8 cylinders  diesel  149000.0
# 37409                      NaN        NaN          NaN     gas    1000.0
# 37410                      NaN        NaN  8 cylinders     gas    1000.0
# 91576                benz e320        NaN          NaN     gas  100000.0
# 153082                     vnl       fair          NaN   other  200000.0
# 184704                wrangler        NaN          NaN  diesel  103000.0
# 257840               benz s430        NaN          NaN     gas  100000.0
# 318592                  tundra  excellent  8 cylinders     gas  164000.0
# 356716                 4runner       fair  6 cylinders     gas  211000.0
#
#        title_status transmission  VIN drive       size    type paint_color  \
# 29386         clean    automatic  NaN   rwd  full-size  pickup       white
# 37409         clean    automatic  NaN   4wd        NaN     NaN         NaN
# 37410         clean    automatic  NaN   4wd        NaN     NaN         NaN
# 91576         clean    automatic  NaN   NaN        NaN     NaN         NaN
# 153082        clean       manual  NaN   NaN        NaN     NaN       black
# 184704        clean       manual  NaN   NaN        NaN     SUV         NaN
# 257840        clean    automatic  NaN   NaN        NaN     NaN         NaN
# 318592        clean    automatic  NaN   4wd  full-size  pickup      silver
# 356716        clean    automatic  NaN   4wd   mid-size     NaN       green
#
#         county state              posting_date
# 29386      NaN    ca  2021-04-11T11:40:08-0700
# 37409      NaN    ca  2021-04-28T14:29:17-0700
# 37410      NaN    ca  2021-04-28T14:28:42-0700
# 91576      NaN    de  2021-04-20T08:46:47-0400
# 153082     NaN    in  2021-04-11T11:19:14-0400
# 184704     NaN    md  2021-04-09T16:02:34-0400
# 257840     NaN    nj  2021-04-20T08:59:55-0400
# 318592     NaN    or  2021-04-16T18:16:12-0700
# 356716     NaN    tn  2021-04-05T23:15:48-0400

# %%
df[df.price.apply(lambda x: True if len(str(x))==9 else False)][cols_main]
# Out:
#                          region      price    year manufacturer  \
# 280                  birmingham  987654321  1960.0    chevrolet
# 122470                  atlanta  987654321  1960.0    chevrolet
# 137807  spokane / coeur d'alene  123456789  1999.0        buick
# 193736                ann arbor  123456789  2015.0    chevrolet
# 207080                 muskegon  123456789  2003.0          NaN
# 230753                asheville  135008900  2008.0       nissan
# 241404    raleigh / durham / CH  113456789  1980.0          bmw
# 288356           akron / canton  123456789  1965.0    chevrolet
# 307488               stillwater  123456789  1996.0          gmc
# 358555                nashville  123456789  2021.0          NaN
#
#                    model condition    cylinders    fuel   odometer  \
# 280                  NaN       NaN          NaN     gas   999999.0
# 122470               NaN       NaN          NaN     gas  9999999.0
# 137807             regal  like new  6 cylinders     gas    96000.0
# 193736             cruze  like new          NaN     gas    64181.0
# 207080         Chevy/gmc      good  8 cylinders  diesel  1234567.0
# 230753  titan se kingcab  like new  8 cylinders     gas   110500.0
# 241404               NaN       NaN          NaN     gas   100000.0
# 288356           project       NaN          NaN     gas   100000.0
# 307488       sierra 2500      fair  8 cylinders     gas   320000.0
# 358555          Rare Car      good  8 cylinders     gas        0.0
#
#        title_status transmission                VIN drive       size    type  \
# 280           clean       manual                NaN   NaN        NaN     NaN
# 122470        clean       manual                NaN   NaN        NaN     NaN
# 137807        clean    automatic                NaN   fwd  full-size   sedan
# 193736        clean    automatic  1G1PC5SB0F7246637   fwd    compact   sedan
# 207080        clean    automatic                NaN   fwd        NaN  pickup
# 230753        clean    automatic                NaN   4wd  full-size   truck
# 241404        clean    automatic                NaN   NaN        NaN     NaN
# 288356        clean    automatic                NaN   NaN        NaN     NaN
# 307488        clean    automatic                NaN   4wd  full-size  pickup
# 358555        clean        other                NaN   rwd        NaN     NaN
#
#        paint_color  county state              posting_date
# 280            NaN     NaN    al  2021-05-02T13:24:09-0500
# 122470         NaN     NaN    ga  2021-05-02T14:00:40-0400
# 137807       white     NaN    id  2021-04-29T08:48:15-0700
# 193736         red     NaN    mi  2021-05-01T17:44:14-0400
# 207080         NaN     NaN    mi  2021-05-04T13:57:30-0400
# 230753        grey     NaN    nc  2021-04-16T19:22:21-0400
# 241404         NaN     NaN    nc  2021-04-28T08:08:53-0400
# 288356         NaN     NaN    oh  2021-04-05T19:34:36-0400
# 307488       black     NaN    ok  2021-04-07T12:44:56-0500
# 358555         NaN     NaN    tn  2021-05-04T20:08:56-0500

# %%
df[df.price.apply(lambda x: True if len(str(x))==8 else False)][cols_main]
# Out:
#                          region     price    year manufacturer   model  \
# 1838                     dothan  99999999  1993.0         ford  ranger
# 136516  spokane / coeur d'alene  17000000  2007.0          ram    2500
# 286323           akron / canton  12345678  2019.0    chevrolet     NaN
# 286324           akron / canton  12345678  2019.0    chevrolet     NaN
# 288400           akron / canton  12345678  2019.0    chevrolet     NaN
# 288401           akron / canton  12345678  2019.0    chevrolet     NaN
# 300308                mansfield  10004000  2002.0         ford    f350
# 303014               youngstown  12345678  2019.0    chevrolet     NaN
# 303644               youngstown  12345678  2019.0    chevrolet     NaN
# 353641                  jackson  11111111  1966.0    chevrolet     c10
# 379133       mcallen / edinburg  25003000  1991.0    chevrolet  camaro
#
#        condition    cylinders    fuel  odometer title_status transmission  \
# 1838         NaN          NaN     gas   99999.0        clean    automatic
# 136516      good  8 cylinders  diesel  170000.0      rebuilt    automatic
# 286323      good  8 cylinders     gas  100000.0        clean    automatic
# 286324      good  8 cylinders     gas  100000.0        clean    automatic
# 288400      good  8 cylinders     gas  100000.0        clean    automatic
# 288401      good  8 cylinders     gas  100000.0        clean    automatic
# 300308       NaN          NaN   other  215000.0        clean        other
# 303014      good  8 cylinders     gas  100000.0        clean    automatic
# 303644      good  8 cylinders     gas  100000.0        clean    automatic
# 353641       NaN          NaN     gas  111111.0        clean    automatic
# 379133      fair  6 cylinders     gas  200000.0        clean    automatic
#
#                       VIN drive       size    type paint_color  county state  \
# 1838                  NaN   NaN        NaN     NaN         NaN     NaN    al
# 136516                NaN   4wd  full-size  pickup       black     NaN    id
# 286323  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 286324  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 288400  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 288401  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 300308                NaN   NaN        NaN     NaN         NaN     NaN    oh
# 303014  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 303644  00000000000000000   4wd  full-size   truck       black     NaN    oh
# 353641                NaN   NaN        NaN     NaN         NaN     NaN    tn
# 379133                NaN   NaN        NaN     NaN         NaN     NaN    tx
#
#                     posting_date
# 1838    2021-05-02T17:18:25-0500
# 136516  2021-05-02T19:27:17-0700
# 286323  2021-05-04T11:31:57-0400
# 286324  2021-05-04T11:31:26-0400
# 288400  2021-04-05T12:28:23-0400
# 288401  2021-04-05T12:26:23-0400
# 300308  2021-05-04T13:40:11-0400
# 303014  2021-05-04T11:30:10-0400
# 303644  2021-04-05T12:34:11-0400
# 353641  2021-05-02T16:36:20-0500
# 379133  2021-04-12T12:36:37-0500

# %%
df[df.price.apply(lambda x: True if len(str(x))==7 else False)][cols_main]
# Out:
#                             region    price    year manufacturer  \
# 26075              fresno / madera  1111111  2014.0    chevrolet
# 68935               ventura county  2000000  2002.0       saturn
# 83367                   eastern CT  1000000  2022.0          NaN
# 87052                    new haven  1000000  2019.0          NaN
# 91605                     delaware  1000000  2022.0          NaN
# 91807                     delaware  1000000  2022.0          NaN
# 105843                     orlando  6995495  2014.0        dodge
# 155421                 terre haute  1234567  2006.0         jeep
# 194292                   ann arbor  1234567  2010.0      lincoln
# 213918       minneapolis / st paul  1111111  1999.0    chevrolet
# 219241                southwest MS  1111111  1970.0        dodge
# 232829                   charlotte  1000000  2016.0         ford
# 233201                   charlotte  1000000  2016.0         ford
# 233823                   charlotte  1000000  2016.0         ford
# 283429               new hampshire  1111111  1994.0    chevrolet
# 283906               new hampshire  5000000  2021.0          NaN
# 286156                north dakota  1666666  1902.0          NaN
# 327938           altoona-johnstown  3226714  2002.0          NaN
# 356959                     memphis  1111111  1966.0    chevrolet
# 362822                     abilene  1234567  1955.0    chevrolet
# 362837                     abilene  1234567  1955.0    chevrolet
# 362867                     abilene  1234567  1955.0    chevrolet
# 367296             college station  1234567  1955.0    chevrolet
# 367308             college station  1234567  1955.0    chevrolet
# 367357             college station  1234567  1955.0    chevrolet
# 377396  killeen / temple / ft hood  1234567  1955.0    chevrolet
# 377425  killeen / temple / ft hood  1234567  1955.0    chevrolet
# 377515  killeen / temple / ft hood  1234567  1955.0    chevrolet
# 384872                        waco  1234567  1955.0    chevrolet
# 384898                        waco  1234567  1955.0    chevrolet
#
#                            model condition    cylinders    fuel   odometer  \
# 26075                        NaN       NaN          NaN   other       11.0
# 68935    l-series l200 4dr sedan      good  4 cylinders     gas   164290.0
# 83367         Any make any model       NaN          NaN   other   364747.0
# 87052   Call for a free estimate       NaN          NaN     gas    12345.0
# 91605         Any make any model       NaN          NaN   other   364747.0
# 91807         Any make any model       NaN          NaN   other   364747.0
# 105843                   journey       NaN  4 cylinders     gas   135888.0
# 155421                  wrangler  like new  6 cylinders     gas   123456.0
# 194292              mkt ecoboost  like new          NaN     gas    85653.0
# 213918                  corvette       NaN          NaN     gas   200000.0
# 219241                challenger      fair  8 cylinders     gas    42000.0
# 232829                      f150       NaN          NaN     gas   100000.0
# 233201                      f150       NaN          NaN     gas   100000.0
# 233823                      f150       NaN          NaN     gas   100000.0
# 283429                  corvette       NaN  8 cylinders     gas  1111111.0
# 283906                       all       NaN          NaN   other        1.0
# 286156                 Recycling       NaN          NaN   other  1111111.0
# 327938               any and all      fair  8 cylinders  diesel     1234.0
# 356959                       c10       NaN          NaN     gas   111111.0
# 362822                       NaN       NaN          NaN   other    99999.0
# 362837                       NaN       NaN          NaN   other    99999.0
# 362867                       NaN       NaN          NaN   other    99999.0
# 367296                       NaN       NaN          NaN   other    99999.0
# 367308                       NaN       NaN          NaN   other    99999.0
# 367357                       NaN       NaN          NaN   other    99999.0
# 377396                       NaN       NaN          NaN   other    99999.0
# 377425                       NaN       NaN          NaN   other    99999.0
# 377515                       NaN       NaN          NaN   other    99999.0
# 384872                       NaN      good          NaN   other    99999.0
# 384898                       NaN      good          NaN   other    99999.0
#
#        title_status transmission                VIN drive       size   type  \
# 26075         clean    automatic                NaN   NaN        NaN    NaN
# 68935         clean    automatic                NaN   fwd   mid-size  sedan
# 83367         clean        other                NaN   NaN        NaN    NaN
# 87052       salvage    automatic  NH738GTD2886R9287   NaN        NaN    NaN
# 91605         clean        other                NaN   NaN        NaN    NaN
# 91807         clean        other                NaN   NaN        NaN    NaN
# 105843        clean    automatic  3C4PDCAB5ET204162   fwd        NaN    SUV
# 155421        clean    automatic                NaN   4wd   mid-size    SUV
# 194292        clean    automatic  2LMHJ5AT1ABJ50124   NaN  full-size    SUV
# 213918        clean    automatic                NaN   NaN        NaN    NaN
# 219241        clean    automatic                NaN   rwd  full-size  coupe
# 232829        clean    automatic                NaN   NaN        NaN    NaN
# 233201        clean    automatic                NaN   NaN        NaN    NaN
# 233823        clean    automatic                NaN   NaN        NaN    NaN
# 283429        clean       manual                NaN   NaN        NaN    NaN
# 283906        clean        other                NaN   NaN        NaN    NaN
# 286156   parts only        other                NaN   NaN        NaN    NaN
# 327938        clean       manual                NaN   4wd   mid-size  sedan
# 356959        clean       manual                NaN   NaN        NaN    NaN
# 362822      missing        other                NaN   NaN        NaN    NaN
# 362837      missing        other                NaN   NaN        NaN    NaN
# 362867      missing        other                NaN   NaN        NaN    NaN
# 367296      missing        other                NaN   NaN        NaN    NaN
# 367308      missing        other                NaN   NaN        NaN    NaN
# 367357      missing        other                NaN   NaN        NaN    NaN
# 377396      missing        other                NaN   NaN        NaN    NaN
# 377425      missing        other                NaN   NaN        NaN    NaN
# 377515      missing        other                NaN   NaN        NaN    NaN
# 384872      missing        other                NaN   NaN        NaN    NaN
# 384898      missing        other                NaN   NaN        NaN    NaN
#
#        paint_color  county state              posting_date
# 26075          NaN     NaN    ca  2021-04-30T12:20:06-0700
# 68935        green     NaN    ca  2021-04-06T16:40:31-0700
# 83367          NaN     NaN    ct  2021-04-11T13:49:50-0400
# 87052          NaN     NaN    ct  2021-04-17T12:33:48-0400
# 91605          NaN     NaN    de  2021-04-19T09:55:42-0400
# 91807          NaN     NaN    de  2021-04-11T13:51:42-0400
# 105843         NaN     NaN    fl  2021-04-28T20:11:41-0400
# 155421      custom     NaN    in  2021-04-18T11:26:55-0400
# 194292      custom     NaN    mi  2021-04-16T15:15:44-0400
# 213918         NaN     NaN    mn  2021-05-04T12:04:16-0500
# 219241        blue     NaN    ms  2021-04-11T19:04:00-0500
# 232829         NaN     NaN    nc  2021-04-28T08:26:48-0400
# 233201         NaN     NaN    nc  2021-04-25T13:05:30-0400
# 233823         NaN     NaN    nc  2021-04-21T15:28:45-0400
# 283429         NaN     NaN    nh  2021-05-02T10:57:23-0400
# 283906         NaN     NaN    nh  2021-04-30T11:57:41-0400
# 286156         NaN     NaN    nd  2021-05-03T08:55:55-0500
# 327938        blue     NaN    pa  2021-04-29T18:24:17-0400
# 356959         NaN     NaN    tn  2021-05-02T16:31:31-0500
# 362822         NaN     NaN    tx  2021-04-09T06:05:33-0500
# 362837         NaN     NaN    tx  2021-04-07T17:14:08-0500
# 362867         NaN     NaN    tx  2021-04-04T17:47:17-0500
# 367296         NaN     NaN    tx  2021-04-09T06:07:06-0500
# 367308         NaN     NaN    tx  2021-04-07T17:12:42-0500
# 367357         NaN     NaN    tx  2021-04-04T17:54:31-0500
# 377396         NaN     NaN    tx  2021-04-09T06:01:57-0500
# 377425         NaN     NaN    tx  2021-04-07T17:16:58-0500
# 377515         NaN     NaN    tx  2021-04-04T17:28:43-0500
# 384872         NaN     NaN    tx  2021-04-09T06:00:14-0500
# 384898         NaN     NaN    tx  2021-04-07T17:21:24-0500

# %% [markdown]
# * drop samples (price >=1e6)

# %%
df[df.price.apply(lambda x: True if len(str(x))==6 else False)][cols_main]
# Out:
#                       region   price    year manufacturer  \
# 732               birmingham  100000  1984.0         jeep
# 1727              birmingham  130000  2019.0    chevrolet
# 2922    huntsville / decatur  140000  2015.0         jeep
# 4797              montgomery  104000  2018.0        dodge
# 4799              montgomery  100000  2018.0        dodge
# ...                      ...     ...     ...          ...
# 419656               madison  119900  2021.0    chevrolet
# 419756               madison  119995  2004.0        acura
# 420693               madison  125000  2014.0      porsche
# 424281             milwaukee  299500  2018.0          NaN
# 426302               wyoming  125000  1957.0    chevrolet
#
#                         model  condition     cylinders   fuel  odometer  \
# 732                       cj7        NaN           NaN    gas  112000.0
# 1727                 corvette   like new   8 cylinders    gas    5000.0
# 2922                 renegade   like new   6 cylinders    gas   49658.0
# 4797                      NaN        NaN   8 cylinders  other     483.0
# 4799                      NaN        NaN   8 cylinders  other     959.0
# ...                       ...        ...           ...    ...       ...
# 419656               corvette       good   8 cylinders    gas     601.0
# 419756                    nsx        NaN   6 cylinders    gas   16859.0
# 420693            911 turbo s  excellent   6 cylinders    gas   10100.0
# 424281  Lamborghini Aventador        NaN  12 cylinders    gas    3171.0
# 426302              resto mod        NaN           NaN    gas     480.0
#
#        title_status transmission                VIN drive         size   type  \
# 732           clean       manual                NaN   NaN          NaN    NaN
# 1727          clean    automatic                NaN   rwd          NaN  coupe
# 2922        rebuilt        other                NaN   fwd     mid-size    SUV
# 4797          clean    automatic  2C3CDZH95JH100203   fwd      compact  other
# 4799          clean    automatic  2C3CDZH98JH100129   fwd      compact  other
# ...             ...          ...                ...   ...          ...    ...
# 419656        clean    automatic  1G1YC2D49M5106953   rwd     mid-size  coupe
# 419756        clean       manual  JH4NA21614T000075   rwd          NaN  coupe
# 420693        clean       manual  WP0AD2A93ES167417   4wd    full-size  coupe
# 424281      salvage    automatic  ZHWUV4ZD4JLA07642   4wd  sub-compact  coupe
# 426302        clean    automatic                NaN   NaN          NaN    NaN
#
#        paint_color  county state              posting_date
# 732            NaN     NaN    al  2021-04-24T00:28:32-0500
# 1727          blue     NaN    al  2021-04-05T22:11:19-0500
# 2922        yellow     NaN    al  2021-04-27T09:21:39-0500
# 4797           NaN     NaN    al  2021-04-05T15:50:38-0500
# 4799           NaN     NaN    al  2021-04-05T15:46:49-0500
# ...            ...     ...   ...                       ...
# 419656         red     NaN    wi  2021-05-04T18:47:19-0500
# 419756       black     NaN    wi  2021-05-04T07:26:45-0500
# 420693       black     NaN    wi  2021-04-23T12:43:37-0500
# 424281        blue     NaN    wi  2021-04-20T22:38:41-0500
# 426302         NaN     NaN    wy  2021-05-03T16:05:46-0600
#
# [637 rows x 19 columns]

# %%
idx_exp = df.price.apply(lambda x: True if len(str(x))==6 else False)

price_grp_model = df[idx_exp].groupby(["manufacturer", "model"])["price"].describe().applymap("{:.0f}".format)
price_grp_model.loc[price_grp_model["count"].astype("float")>=5]
# Out:
#                                                                  count  \
# manufacturer  model
# acura         nsx                                                    5
# cadillac      escalade                                              13
#               escalade esv premium & luxury pkgs rear dvd pan...     5
# chevrolet     camaro                                                 5
#               corvette                                              38
# ferrari       458 spider                                             5
# ford          mustang                                                7
#               super duty f-450 pickup                                6
# mercedes-benz amg gt                                                 9
#               g-class                                               14
# porsche       911                                                   16
# ram           1500 trx launch edition 702hp every option #114...     6
# rover         defender 110                                           6
#
#                                                                     mean  \
# manufacturer  model
# acura         nsx                                                 126376
# cadillac      escalade                                            109823
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              121396
#               corvette                                            115369
# ferrari       458 spider                                          149995
# ford          mustang                                             155384
#               super duty f-450 pickup                             107328
# mercedes-benz amg gt                                              147993
#               g-class                                             149139
# porsche       911                                                 186800
# ram           1500 trx launch edition 702hp every option #114...  131900
# rover         defender 110                                        129888
#
#                                                                     std  \
# manufacturer  model
# acura         nsx                                                 13193
# cadillac      escalade                                             6286
#               escalade esv premium & luxury pkgs rear dvd pan...      0
# chevrolet     camaro                                              11324
#               corvette                                            11402
# ferrari       458 spider                                              0
# ford          mustang                                             52599
#               super duty f-450 pickup                              9812
# mercedes-benz amg gt                                               6016
#               g-class                                             37850
# porsche       911                                                 63494
# ram           1500 trx launch edition 702hp every option #114...   3098
# rover         defender 110                                            0
#
#                                                                      min  \
# manufacturer  model
# acura         nsx                                                 109999
# cadillac      escalade                                            104999
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              109000
#               corvette                                            100000
# ferrari       458 spider                                          149995
# ford          mustang                                             102999
#               super duty f-450 pickup                             100995
# mercedes-benz amg gt                                              131950
#               g-class                                             104995
# porsche       911                                                 112999
# ram           1500 trx launch edition 702hp every option #114...  129900
# rover         defender 110                                        129888
#
#                                                                      25%  \
# manufacturer  model
# acura         nsx                                                 119995
# cadillac      escalade                                            104999
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              109000
#               corvette                                            106999
# ferrari       458 spider                                          149995
# ford          mustang                                             119894
#               super duty f-450 pickup                             100995
# mercedes-benz amg gt                                              149998
#               g-class                                             116248
# porsche       911                                                 156242
# ram           1500 trx launch edition 702hp every option #114...  129900
# rover         defender 110                                        129888
#
#                                                                      50%  \
# manufacturer  model
# acura         nsx                                                 122000
# cadillac      escalade                                            110995
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              129000
#               corvette                                            110000
# ferrari       458 spider                                          149995
# ford          mustang                                             119900
#               super duty f-450 pickup                             100995
# mercedes-benz amg gt                                              149998
#               g-class                                             125998
# porsche       911                                                 159991
# ram           1500 trx launch edition 702hp every option #114...  129900
# rover         defender 110                                        129888
#
#                                                                      75%  \
# manufacturer  model
# acura         nsx                                                 139888
# cadillac      escalade                                            111111
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              129991
#               corvette                                            125000
# ferrari       458 spider                                          149995
# ford          mustang                                             200000
#               super duty f-450 pickup                             115245
# mercedes-benz amg gt                                              149998
#               g-class                                             179988
# porsche       911                                                 191498
# ram           1500 trx launch edition 702hp every option #114...  134400
# rover         defender 110                                        129888
#
#                                                                      max
# manufacturer  model
# acura         nsx                                                 139999
# cadillac      escalade                                            126995
#               escalade esv premium & luxury pkgs rear dvd pan...  126900
# chevrolet     camaro                                              129991
#               corvette                                            152995
# ferrari       458 spider                                          149995
# ford          mustang                                             225000
#               super duty f-450 pickup                             119995
# mercedes-benz amg gt                                              149998
#               g-class                                             199999
# porsche       911                                                 304995
# ram           1500 trx launch edition 702hp every option #114...  135900
# rover         defender 110                                        129888

# %%
idx_0 = df.price == 0

df[idx_0][cols_main].describe(include="all")
# Out:
#        region    price          year manufacturer  model  condition  \
# count   32895  32895.0  32863.000000        31434  32319      10180
# unique    383      NaN           NaN           40   4172          6
# top     salem      NaN           NaN         ford  f-150  excellent
# freq      780      NaN           NaN         6130    893       6542
# mean      NaN      0.0   2013.973344          NaN    NaN        NaN
# std       NaN      0.0      6.359100          NaN    NaN        NaN
# min       NaN      0.0   1903.000000          NaN    NaN        NaN
# 25%       NaN      0.0   2012.000000          NaN    NaN        NaN
# 50%       NaN      0.0   2015.000000          NaN    NaN        NaN
# 75%       NaN      0.0   2017.000000          NaN    NaN        NaN
# max       NaN      0.0   2022.000000          NaN    NaN        NaN
#
#           cylinders   fuel      odometer title_status transmission  \
# count         15627  32476  3.078500e+04        32387        32162
# unique            8      5           NaN            6            3
# top     6 cylinders    gas           NaN        clean    automatic
# freq           5322  25778           NaN        32250        29713
# mean            NaN    NaN  8.931268e+04          NaN          NaN
# std             NaN    NaN  2.970072e+05          NaN          NaN
# min             NaN    NaN  0.000000e+00          NaN          NaN
# 25%             NaN    NaN  3.490800e+04          NaN          NaN
# 50%             NaN    NaN  7.200000e+04          NaN          NaN
# 75%             NaN    NaN  1.100000e+05          NaN          NaN
# max             NaN    NaN  1.000000e+07          NaN          NaN
#
#                       VIN  drive       size   type paint_color  county  state  \
# count               24011  22582       9467  25969       19841     0.0  32895
# unique              13174      3          4     13          12     NaN     51
# top     5B4KPD27X83433783    4wd  full-size  sedan       white     NaN     ca
# freq                   88  11233       4956   6734        6425     NaN   5255
# mean                  NaN    NaN        NaN    NaN         NaN     NaN    NaN
# std                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
# min                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
# 25%                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
# 50%                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
# 75%                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
# max                   NaN    NaN        NaN    NaN         NaN     NaN    NaN
#
#                     posting_date
# count                      32889
# unique                     32378
# top     2021-05-04T07:40:20-0400
# freq                           7
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
idx_drop = (df.price >= 1.e5) | (df.price < 500)

# %% [markdown]
# ### 6. year

# %%
df.year.describe()
# Out:
# count    425675.000000
# mean       2011.235191
# std           9.452120
# min        1900.000000
# 25%        2008.000000
# 50%        2013.000000
# 75%        2017.000000
# max        2022.000000
# Name: year, dtype: float64

# %%
df.year.hist(bins=np.arange(1900, 2025, 5), edgecolor="k")
plt.show()

# %% [markdown]
# ### 7. manufacturer

# %% [markdown]
# * land rover = rover

# %%
col = "manufacturer"
df[col].nunique()
# Out:
# 42

# %%
fig, ax = plt.subplots(figsize=(4, 8))
sns.countplot(data=df, y=col, 
              order=df[col].value_counts().index, 
              ax=ax)
plt.show()

# %% [markdown]
# #### 7.1. manufacturer with price

# %%
fig, ax = plt.subplots(figsize=(12,4))
lbs = df[~idx_drop][col].value_counts().index
sns.boxplot(data=df[~idx_drop], y='price', x=col, order=lbs, ax=ax)
ax.set_xticklabels(lbs, rotation=90)
plt.show()

# %%
df[~idx_drop].groupby([col])["price"].describe().sort_values("mean").applymap("{:.1f}".format)
# Out:
#                    count     mean      std     min      25%      50%      75%  \
# manufacturer
# saturn            1060.0   5187.2   4175.9   500.0   2995.0   4235.5   5495.0
# mercury           1081.0   5990.6   6201.6   500.0   3000.0   4500.0   6495.0
# pontiac           2209.0   8420.5   9486.7   500.0   3499.0   4995.0   8846.0
# chrysler          5529.0  11113.2   8885.7   500.0   4850.0   7999.0  15598.0
# honda            19408.0  11770.7   8423.5   500.0   5500.0   9250.0  16000.0
# hyundai           9130.0  12133.3   7096.9   500.0   6857.2  10900.0  16990.0
# fiat               754.0  12487.1   6984.0   500.0   6500.0  10675.0  19990.0
# kia               7309.0  12819.0   7596.4   500.0   7250.0  11988.0  16990.0
# morgan               3.0  13100.0  20268.9  1000.0   1400.0   1800.0  19150.0
# nissan           16949.0  13185.2   9577.0   500.0   6000.0  10500.0  17990.0
# mazda             4930.0  13585.2   9225.0   500.0   5975.0  10225.0  19990.8
# harley-davidson    136.0  13643.2   6741.6  2500.0   7998.8  11975.0  18623.8
# volkswagen        8511.0  13723.6   8435.1   500.0   6990.0  12488.0  18950.0
# subaru            8772.0  14090.1   8838.6   500.0   6998.0  11995.0  19990.0
# mitsubishi        3008.0  15030.5   8679.1   500.0   6900.0  15990.0  20990.0
# land rover          11.0  15103.0  18222.5  3199.0   5747.5   7995.0  10499.5
# mini              2214.0  15196.1   9140.8   600.0   7749.2  12998.0  21560.0
# buick             5101.0  15418.5  11345.7   500.0   5950.0  12995.0  22590.0
# datsun              59.0  16176.1   9112.9  2200.0   7749.5  18500.0  23000.0
# dodge            11675.0  16524.5  13373.7   500.0   6198.5  12499.0  24900.0
# toyota           30927.0  17431.7  12632.8   500.0   6995.0  13995.0  25995.0
# volvo             3252.0  18472.1  14634.4   500.0   5900.0  13990.5  29990.0
# chevrolet        49509.0  20202.2  15345.0   500.0   7990.0  16000.0  29900.0
# jeep             16828.0  20311.3  12940.8   500.0   9495.0  18900.0  29499.0
# lincoln           4000.0  20527.7  13594.2   541.0   8537.5  18500.0  29991.2
# cadillac          6462.0  20528.5  14468.2   500.0   8500.0  17500.0  31590.0
# lexus             7590.0  20716.4  11766.8   500.0  10500.0  19999.0  29900.0
# bmw              13305.0  20953.8  12876.8   500.0  11000.0  18500.0  28990.0
# ford             63831.0  21226.4  15879.4   500.0   8500.0  17000.0  30590.0
# acura             5551.0  21248.2  12438.4   500.0  10400.0  20000.0  30995.0
# infiniti          4406.0  21318.0  10991.3   500.0  11995.0  21590.0  28990.0
# mercedes-benz    10013.0  22195.8  15267.6   500.0  10700.0  19640.0  30990.0
# audi              6984.0  25014.4  13814.6   500.0  13999.0  24990.0  33642.5
# gmc              15212.0  25271.0  16939.9   500.0  10999.0  24200.0  34990.0
# jaguar            1871.0  27289.6  13904.3   500.0  16245.0  28990.0  36533.5
# rover             1922.0  28852.2  18318.8   500.0  14999.0  25995.0  38995.0
# alfa-romeo         857.0  29553.8   5365.9  1000.0  27990.0  29590.0  30990.0
# ram              16152.0  30283.5  15609.0   500.0  19000.0  29995.0  39990.0
# porsche           1247.0  30770.6  18334.9   560.0  15948.0  29950.0  39950.0
# tesla              834.0  39663.0  13447.8   500.0  32990.0  37990.0  40990.0
# aston-martin        18.0  46560.6  29556.5  1947.0  33925.0  46997.5  69997.5
# ferrari             38.0  72810.5  31468.1  2034.0  80791.0  85500.0  88800.0
#
#                      max
# manufacturer
# saturn           22000.0
# mercury          95000.0
# pontiac          98000.0
# chrysler         86000.0
# honda            69891.0
# hyundai          50000.0
# fiat             32500.0
# kia              55325.0
# morgan           36500.0
# nissan           99990.0
# mazda            45000.0
# harley-davidson  39900.0
# volkswagen       60000.0
# subaru           49999.0
# mitsubishi       40000.0
# land rover       55000.0
# mini             42500.0
# buick            99000.0
# datsun           30000.0
# dodge            99000.0
# toyota           98772.0
# volvo            70998.0
# chevrolet        99999.0
# jeep             99999.0
# lincoln          99500.0
# cadillac         89999.0
# lexus            98000.0
# bmw              95000.0
# ford             99999.0
# acura            95000.0
# infiniti         69995.0
# mercedes-benz    99995.0
# audi             99991.0
# gmc              90000.0
# jaguar           75000.0
# rover            96995.0
# alfa-romeo       62950.0
# ram              99981.0
# porsche          98995.0
# tesla            95000.0
# aston-martin     92995.0
# ferrari          99999.0

# %% [markdown]
# #### 7.2. manufacturer with model

# %%
df.groupby([col])["model"].nunique().sort_values(ascending=False)
# Out:
# manufacturer
# ford               3874
# chevrolet          2611
# toyota             1721
# mercedes-benz      1201
# gmc                1173
# bmw                1129
# ram                1038
# honda              1021
# nissan              993
# dodge               826
# jeep                772
# volkswagen          704
# audi                646
# subaru              610
# hyundai             490
# lexus               463
# kia                 437
# cadillac            432
# mazda               415
# volvo               376
# chrysler            351
# infiniti            341
# buick               337
# acura               315
# lincoln             251
# mitsubishi          224
# pontiac             205
# jaguar              203
# porsche             178
# rover               168
# mini                163
# mercury             111
# saturn              102
# fiat                 66
# tesla                62
# harley-davidson      51
# alfa-romeo           38
# ferrari              31
# datsun               20
# aston-martin         12
# land rover            8
# morgan                0
# Name: model, dtype: int64

# %% [markdown]
# ### 8. model

# %% [markdown]
# * cleansing required by manufacturer

# %%
col = "model"
df[col].isna().sum(), df[col].nunique()
# Out:
# (5277, 29667)

# %%
display(df[df.manufacturer=="ford"]["model"].value_counts().sort_index()[:20])
display(df[df.manufacturer=="ford"]["model"].value_counts().sort_index()[20:40])
display(df[df.manufacturer=="ford"]["model"].value_counts().sort_index()[-20:])
# Out:
# "t"                         1
# - mustang                   1
# -150 xlt                    1
# -350                        1
# .. ect.                     3
# /vmi conversion van         1
# 100                         2
# 15 passenger shuttle van    2
# 150                         6
# 150 4wd                     1
# 150 4x4                     1
# 150 full size van i         1
# 150 xlt                     1
# 150 xlt 4x4                 1
# 1930 shay repoduction       1
# 1952                        1
# 1959 f-100                  1
# 2 door sedan                2
# 2 dr sedan                  1
# 2 dr victoria               1
# Name: model, dtype: int64
# 2004 f350 super duty                         1
# 2011 f-450 4x4 crew cab in-closed utility    3
# 2017 f-350 ex-cab service utility truck      3
# 2018 f-250 4x4 crew-cab flatbed truck        3
# 23 t                                         1
# 24 ft                                        1
# 250                                          9
# 250 super duty xl                            1
# 250 xlt                                      1
# 2door deluxe sedan                           1
# 2dr sedan                                    3
# 3 window                                     1
# 3 window pro street coupe                    1
# 350                                          2
# 350 4×4 dauly                                1
# 350 closed utility                           1
# 350 super duty van                           1
# 350 supercab 4x4                             1
# 350 transit high roof                        1
# 3500                                         3
# Name: model, dtype: int64
# windstar minivan            1
# windstar passenger sport    1
# windstar se                 3
# windstar sel                4
# windstar van                8
# windstar wagon              1
# windstard                   1
# winstar                     3
# winstar lx                  1
# winstar van                 1
# workhorse                   1
# xl                          1
# xl convertible              1
# xls explorer                1
# xlt                         1
# xlt econoline e350          1
# xlt f-350 diesel 4x4        4
# xlt f150                    1
# xlt x-cab                   1
# zx2                         1
# Name: model, dtype: int64

# %%
df[df.manufacturer=="ford"][["model", "type", "drive", "transmission"]].sample(15)
# Out:
#                            model    type drive transmission
# 237127             edge titanium     NaN   NaN    automatic
# 61195                      f-150     NaN   rwd    automatic
# 365470                     f-150  pickup   NaN    automatic
# 352339         excursion limited     SUV   rwd    automatic
# 39196                  fusion se   sedan   fwd    automatic
# 197389                      f250     NaN   4wd    automatic
# 369690  fusion platinum sedan 4d   sedan   fwd        other
# 79955                      f-550   other   4wd    automatic
# 132883                   mustang   coupe   fwd       manual
# 32511                 expedition   truck   4wd    automatic
# 165770            crown victoria   sedan   rwd    automatic
# 321268                   transit     van   NaN    automatic
# 330056                 focus zx4     NaN   fwd    automatic
# 276030           e350 super duty     van   rwd    automatic
# 108575                expedition     SUV   4wd    automatic

# %%
display(df[df.manufacturer=="tesla"]["model"].value_counts().sort_index())
# display(df[df.manufacturer=="ford"]["model"].value_counts().sort_index()[20:40])
# display(df[df.manufacturer=="ford"]["model"].value_counts().sort_index()[-20:])
# Out:
# 3                                            1
# 3 standard range plus                        1
# 75                                           1
# model 3                                     73
# model 3 awd dual moter                       1
# model 3 blacked out standard range plus      5
# model 3 long range                           1
# model 3 long range sedan                    18
# model 3 mid range                            2
# model 3 mid range sedan 4d                  16
# model 3 performance                          3
# model 3 s x y                                1
# model 3 standard range                     275
# model 60s                                    1
# model s                                    108
# model s 100d                                 2
# model s 100d awd                             2
# model s 70                                   2
# model s 70 kwh battery                       1
# model s 75                                   4
# model s 75d                                  2
# model s 75d - autopilot                      3
# model s 85d                                  1
# model s 90d                                  1
# model s base                                 2
# model s p85                                  5
# model s p85d                                 4
# model s p85d 4dr liftbac                     2
# model s p85d awd 100% elec                   2
# model s p90d                                 3
# model s performance                          8
# model s performance sedan                   10
# model s rwd                                  3
# model s sdn                                  1
# model s sdn awd 85d                          1
# model s sedan 4d                            38
# model s signature                          126
# model sp90d                                  1
# model x                                     37
# model x - auto pilot                         1
# model x 100d                                 1
# model x 100d awd 518+hp                      3
# model x 75d                                  2
# model x 75d sport utility                    5
# model x 90d sport utility                   15
# model x p100d                                2
# model x p90d awd                             7
# model y                                      3
# modle s 75d                                  1
# p100d                                        1
# s                                           19
# s 85                                         3
# s 90d                                        5
# s model 90d                                  1
# s p100d                                      1
# s p85                                        1
# s p85+                                       3
# s p85d                                       2
# s p90d                                       2
# x                                            4
# x p90d                                       1
# y performance                                1
# Name: model, dtype: int64

# %% [markdown]
# ### 9. condition

# %%
col = "condition"
df[col].value_counts()
# Out:
# good         121456
# excellent    101467
# like new      21178
# fair           6769
# new            1305
# salvage         601
# Name: condition, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,4))
lbs = ["salvage", "fair", "good", "excellent", "like new", "new"]
sns.boxplot(data=df[~idx_drop], y='price', x=col, order=lbs, ax=ax)
ax.set_xticklabels(lbs)
plt.show()

# %%
df[~idx_drop].groupby([col])["price"].describe().sort_values("mean").applymap("{:.1f}".format)
# Out:
#               count     mean      std    min     25%      50%      75%  \
# condition
# salvage       552.0   3906.6   4796.1  500.0  1000.0   2000.0   4961.2
# fair         6626.0   4039.1   4558.2  500.0  1600.0   2800.0   4965.0
# excellent   92559.0  15690.9  12300.3  500.0  7250.0  11998.0  19991.0
# like new    19550.0  19285.4  15309.7  500.0  7998.0  14995.0  26495.0
# good       118540.0  21037.7  13076.9  500.0  8500.0  20990.0  30990.0
# new           986.0  28032.4  21921.6  500.0  9825.0  22942.5  41000.0
#
#                max
# condition
# salvage    35989.0
# fair       85000.0
# excellent  99999.0
# like new   99995.0
# good       98900.0
# new        99999.0

# %% [markdown]
# * "good" is more expensive than "excellent"

# %% [markdown]
# ### 10. cylinders

# %%
col = "cylinders"
df[~idx_drop][col].value_counts()
# Out:
# 6 cylinders     86829
# 4 cylinders     70311
# 8 cylinders     65473
# 5 cylinders      1649
# 10 cylinders     1120
# other            1060
# 3 cylinders       586
# 12 cylinders      164
# Name: cylinders, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,4))
lbs = [f"{i} cylinders" for i in [3, 4, 5, 6, 8, 10, 12]] + ["others"]
sns.boxplot(data=df[~idx_drop], y='price', order=lbs, x=col, ax=ax)
plt.show()

# %% [markdown]
# #### 10.1. cylinders with type

# %%
df.groupby([col, "type"]).size().unstack().fillna(0).astype('int')
# Out:
# type            SUV  bus  convertible  coupe  hatchback  mini-van  offroad  \
# cylinders
# 10 cylinders    116   66           24     61          1         0        1
# 12 cylinders     12    0           29     48          0         0        0
# 3 cylinders     110   12           18     74        113         6        0
# 4 cylinders   18267   48         1373   3215       5857       288       98
# 5 cylinders     159    0           60     75        101         6        4
# 6 cylinders   27731  114         1852   3973        469      3388      341
# 8 cylinders    9401  132         2043   5807        148        36      133
# other           155   22           43     78        107         1        4
#
# type          other  pickup  sedan  truck   van  wagon
# cylinders
# 10 cylinders     43      98    172    534    55     38
# 12 cylinders      7       3     77     10     0      0
# 3 cylinders      44       5    143     37     7     29
# 4 cylinders    1314     775  32362   1257  1001   3687
# 5 cylinders      20      97    695     98    31    165
# 6 cylinders    5383    9868  18363   7889  3953   1387
# 8 cylinders    2367   16129   5115  19256  1893    250
# other           219      52    187    150    13     13

# %% [markdown]
# #### 10.2. cylinders with year

# %%
df.groupby([col])["year"].describe().applymap("{:.0f}".format)
# Out:
#               count  mean std   min   25%   50%   75%   max
# cylinders
# 10 cylinders   1448  2010   7  1968  2003  2010  2015  2021
# 12 cylinders    209  2005  10  1948  2002  2007  2010  2022
# 3 cylinders     648  2012  11  1929  2009  2017  2019  2021
# 4 cylinders   77293  2012   8  1900  2009  2013  2016  2022
# 5 cylinders    1712  2008   6  1963  2006  2008  2012  2020
# 6 cylinders   93700  2011   8  1920  2007  2013  2017  2022
# 8 cylinders   71776  2008  13  1905  2005  2012  2016  2022
# other          1298  2008  18  1900  2007  2014  2018  2022

# %% [markdown]
# ### 11. fuel

# %%
col = "fuel"
df[~idx_drop][col].value_counts()
# Out:
# gas         321801
# other        27392
# diesel       25953
# hybrid        4757
# electric      1596
# Name: fuel, dtype: int64

# %% [markdown]
# #### 11.1. fuel with price

# %%
fig, ax = plt.subplots(figsize=(8,4))
sns.boxplot(data=df[~idx_drop], y='price', x=col, ax=ax)
plt.show()

# %%
df[~idx_drop].groupby([col])["price"].describe().sort_values("mean").applymap("{:.0f}".format)
# Out:
#            count   mean    std  min    25%    50%    75%    max
# fuel
# hybrid      4757  15820  11022  521   7800  12995  19990  90000
# gas       321801  17203  12979  500   6995  13990  24995  99999
# electric    1596  26007  16133  500  12590  25590  37590  95000
# other      27392  28257  12936  500  19590  27990  34990  99950
# diesel     25953  33769  19732  500  17995  31998  46990  99700

# %% [markdown]
# * hibrid < gas < electric < other < diesel

# %% [markdown]
# #### 11.2. fuel with price, type

# %%
# most expensive fuel by type (price: mean)
prc_grp_type_fuel = df[~idx_drop].groupby(["type", "fuel"])["price"].mean().reset_index()
prc_grp_type_fuel.loc[prc_grp_type_fuel.groupby(["type"])["price"].idxmax()]
# Out:
#            type      fuel         price
# 1           SUV  electric  37171.806202
# 5           bus    diesel  15594.699029
# 12  convertible    hybrid  35124.945946
# 18        coupe     other  29897.036943
# 23    hatchback     other  21997.960354
# 24     mini-van    diesel  15662.888889
# 28      offroad    diesel  24493.000000
# 35        other     other  33541.438935
# 36       pickup    diesel  38031.928743
# 42        sedan  electric  32977.441691
# 46        truck    diesel  37157.597308
# 51          van    diesel  27084.810811
# 57        wagon  electric  22238.195122

# %%
# most expensive fuel by type (price: median)
prc_grp_type_fuel = df[~idx_drop].groupby(["type", "fuel"])["price"].median().reset_index()
prc_grp_type_fuel.loc[prc_grp_type_fuel.groupby(["type"])["price"].idxmax()]
# Out:
#            type      fuel    price
# 4           SUV     other  27590.0
# 7           bus       gas  14900.0
# 12  convertible    hybrid  36197.0
# 18        coupe     other  30990.0
# 23    hatchback     other  19990.0
# 24     mini-van    diesel  14500.0
# 28      offroad    diesel  18000.0
# 35        other     other  32990.0
# 36       pickup    diesel  36990.0
# 42        sedan  electric  32990.0
# 46        truck    diesel  35000.0
# 51          van    diesel  26995.0
# 60        wagon     other  18990.0

# %% [markdown]
# ### 12. odometer

# %%
col = "odometer"
df[col].describe()
# Out:
# count    4.224800e+05
# mean     9.804333e+04
# std      2.138815e+05
# min      0.000000e+00
# 25%      3.770400e+04
# 50%      8.554800e+04
# 75%      1.335425e+05
# max      1.000000e+07
# Name: odometer, dtype: float64

# %%
# 1%, 5%, 10%, 80%, 90%, 95%, 99%
np.quantile(df[df[col].notnull()][col], [0.01, 0.05, 0.1, 0.8, 0.9, 0.95, 0.99])
# Out:
# array([2.000000e+00, 6.318000e+03, 1.493900e+04, 1.457170e+05,
#        1.773771e+05, 2.040000e+05, 2.800000e+05])

# %% [markdown]
# #### 12.1. outliers

# %%
# drop odometer=0
idx = df[col] == 0
df[idx][cols_main]
# Out:
#             region  price    year manufacturer             model condition  \
# 538     birmingham      0  2012.0    chevrolet  silverado 2500hd       NaN
# 563     birmingham      0  2006.0         ford              f550       NaN
# 694     birmingham   3980  2013.0          kia               rio       NaN
# 889     birmingham      0  2006.0         jeep           liberty       NaN
# 985     birmingham      0  2011.0    chevrolet             cruze       NaN
# ...            ...    ...     ...          ...               ...       ...
# 425904      wausau      0  2014.0          ram               NaN       NaN
# 425905      wausau      0  2014.0          ram               NaN       NaN
# 426002      wausau      0  2014.0          ram               NaN       NaN
# 426518     wyoming      0  2014.0          ram               NaN       NaN
# 426638     wyoming      0  2015.0        dodge            intern       NaN
#
#           cylinders    fuel  odometer title_status transmission  \
# 538     8 cylinders     NaN       0.0        clean    automatic
# 563             NaN  diesel       0.0        clean        other
# 694     4 cylinders     gas       0.0          NaN       manual
# 889     6 cylinders     gas       0.0        clean    automatic
# 985     4 cylinders     gas       0.0        clean    automatic
# ...             ...     ...       ...          ...          ...
# 425904          NaN  diesel       0.0        clean    automatic
# 425905          NaN  diesel       0.0        clean    automatic
# 426002          NaN  diesel       0.0        clean    automatic
# 426518          NaN  diesel       0.0        clean    automatic
# 426638          NaN  diesel       0.0        clean        other
#
#                       VIN drive size   type paint_color  county state  \
# 538     1GC1CVCG6CF139696   rwd  NaN    NaN       white     NaN    al
# 563                   NaN   NaN  NaN  other       white     NaN    al
# 694     KNADM4A30D6171594   fwd  NaN  sedan       white     NaN    al
# 889     1J8GL48K06W123802   4wd  NaN    SUV         red     NaN    al
# 985     1G1PJ5S98B7275266   rwd  NaN  sedan         red     NaN    al
# ...                   ...   ...  ...    ...         ...     ...   ...
# 425904                NaN   NaN  NaN  other       white     NaN    wi
# 425905                NaN   NaN  NaN  other       white     NaN    wi
# 426002                NaN   NaN  NaN  other       white     NaN    wi
# 426518                NaN   NaN  NaN  other       white     NaN    wy
# 426638  14141414141414141   NaN  NaN  other       white     NaN    wy
#
#                     posting_date
# 538     2021-04-27T19:50:22-0500
# 563     2021-04-27T14:10:03-0500
# 694     2021-04-24T13:50:11-0500
# 889     2021-04-22T17:40:42-0500
# 985     2021-04-20T13:20:43-0500
# ...                          ...
# 425904  2021-04-20T19:33:56-0500
# 425905  2021-04-20T19:30:08-0500
# 426002  2021-04-16T02:00:05-0500
# 426518  2021-04-21T22:45:37-0600
# 426638  2021-04-15T10:40:07-0600
#
# [1965 rows x 19 columns]

# %%
# drop odometer=0 and price outliers
df[idx&(~idx_drop)][cols_main]
# Out:
#             region  price    year manufacturer        model condition  \
# 694     birmingham   3980  2013.0          kia          rio       NaN
# 1720    birmingham  10477  2009.0    chevrolet     colorado       NaN
# 1804    birmingham  11980  2013.0     infiniti    g37 sedan       NaN
# 3959        mobile   4500  1997.0          gmc       sierra      good
# 4267        mobile   4250  1995.0         ford         f150      good
# ...            ...    ...     ...          ...          ...       ...
# 417977   green bay  16900  2013.0         ford        e-350       NaN
# 418235  janesville   4900  2011.0          NaN  IC CE PB105       NaN
# 421403     madison    999  2019.0         ford      transit       NaN
# 423311   milwaukee   4900  2011.0          NaN  IC CE PB105       NaN
# 424282   milwaukee   3500  1969.0     cadillac      deville      good
#
#           cylinders    fuel  odometer title_status transmission  \
# 694     4 cylinders     gas       0.0          NaN       manual
# 1720            NaN     gas       0.0        clean    automatic
# 1804    6 cylinders     gas       0.0          NaN    automatic
# 3959    6 cylinders     gas       0.0        clean    automatic
# 4267    8 cylinders     gas       0.0        clean    automatic
# ...             ...     ...       ...          ...          ...
# 417977          NaN     gas       0.0        clean        other
# 418235          NaN  diesel       0.0        clean        other
# 421403          NaN     gas       0.0        clean    automatic
# 423311          NaN  diesel       0.0        clean        other
# 424282  8 cylinders     gas       0.0        clean    automatic
#
#                       VIN drive       size         type paint_color  county  \
# 694     KNADM4A30D6171594   fwd        NaN        sedan       white     NaN
# 1720    1GCCS139X98156780   NaN        NaN          NaN       black     NaN
# 1804    JN1CV6AP2DM300508   rwd        NaN        sedan      silver     NaN
# 3959                  NaN   rwd   mid-size        truck        blue     NaN
# 4267                  NaN   rwd  full-size       pickup       white     NaN
# ...                   ...   ...        ...          ...         ...     ...
# 417977                NaN   NaN        NaN        other       white     NaN
# 418235                NaN   NaN        NaN          bus      yellow     NaN
# 421403                NaN   NaN        NaN          NaN         NaN     NaN
# 423311                NaN   NaN        NaN          bus      yellow     NaN
# 424282                NaN   rwd  full-size  convertible        blue     NaN
#
#        state              posting_date
# 694       al  2021-04-24T13:50:11-0500
# 1720      al  2021-04-06T08:46:53-0500
# 1804      al  2021-04-04T11:10:27-0500
# 3959      al  2021-04-28T07:51:45-0500
# 4267      al  2021-04-14T21:18:18-0500
# ...      ...                       ...
# 417977    wi  2021-04-05T15:07:48-0500
# 418235    wi  2021-04-19T14:07:54-0500
# 421403    wi  2021-04-14T09:10:22-0500
# 423311    wi  2021-04-27T15:27:02-0500
# 424282    wi  2021-04-20T22:08:49-0500
#
# [1063 rows x 19 columns]

# %%
df[idx & (~idx_drop)]["condition"].value_counts(dropna=False)
# Out:
# excellent    529
# NaN          409
# good          79
# fair          25
# like new      10
# new            7
# salvage        4
# Name: condition, dtype: int64

# %%
df[idx & (~idx_drop)]["title_status"].value_counts(dropna=False)
# Out:
# clean         787
# NaN           251
# missing        10
# parts only      8
# rebuilt         5
# salvage         2
# Name: title_status, dtype: int64

# %%
# count year where odometer = 0
fig, ax = plt.subplots(figsize=(10,4))
df[idx&(~idx_drop)]["year"].hist(bins=np.arange(1900, 2025, 2), edgecolor="k", ax=ax)
ax.set_title(f"{col}=0")
plt.show()

# %%
idx_drop = (df.price>=1.e5) | (df.price<500) | (df.odometer<100) | (df.odometer>=3e5)
idx_drop.sum()
# Out:
# 50239

# %%
df_pl = df[~idx_drop]

plt.figure(figsize=(6,6))
plt.scatter(df_pl["odometer"], df_pl["price"], s=3, alpha=0.5)
plt.show()

# %%
cat = "fuel"
lbs = df[df[cat].notnull()][cat].unique()

fig, axs = plt.subplots(figsize=(10,6), ncols=3, nrows=2)
for ax, lb in zip(axs.flatten(), lbs):
    
    sns.scatterplot(data=df_pl[df_pl[cat]==lb], 
                    x="odometer", y="price", 
                    s=3, alpha=0.5, 
                    ax=ax)

    ax.set_title(lb)
    ax.set_xlim(0, 300000)
    ax.set_ylim(0, 100000)

plt.tight_layout()
plt.show()

# %%
cat = "condition"
lbs = df[df[cat].notnull()][cat].unique()

fig, axs = plt.subplots(figsize=(10,6), ncols=3, nrows=2)
for ax, lb in zip(axs.flatten(), lbs):
    
    sns.scatterplot(data=df_pl[df_pl[cat]==lb], 
                    x="odometer", y="price", 
                    s=3, alpha=0.5, 
                    ax=ax)

    ax.set_title(lb)
    ax.set_xlim(0, 300000)
    ax.set_ylim(0, 100000)

plt.tight_layout()
plt.show()

# %%
cat = "title_status"
lbs = df[df[cat].notnull()][cat].unique()

fig, axs = plt.subplots(figsize=(10,6), ncols=3, nrows=2)
for ax, lb in zip(axs.flatten(), lbs):
    
    sns.scatterplot(data=df_pl[df_pl[cat]==lb], 
                    x="odometer", y="price", 
                    s=3, alpha=0.5, 
                    ax=ax)

    ax.set_title(lb)
    ax.set_xlim(0, 300000)
    ax.set_ylim(0, 100000)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 13. title_status

# %%
col = "title_status"
df[col].value_counts()
# Out:
# clean         405117
# rebuilt         7219
# salvage         3868
# lien            1422
# missing          814
# parts only       198
# Name: title_status, dtype: int64

# %% [markdown]
# ### 13.1. title_status with condition

# %%
df.groupby([col, "condition"]).size().unstack()
# Out:
# condition     excellent  fair    good  like new   new  salvage
# title_status
# clean             91734  6156  118461     19870  1226      225
# lien                586    47     389       265    25        3
# missing              57   188     208         8     5       49
# parts only           18    27      29         9     4       41
# rebuilt            2823   142    1362       791    30       23
# salvage             880   209     893       235    15      260

# %% [markdown]
# * (title_status)="clean" -> (conditon)="salvage" : 225
# * (title_status)="salvage" -> (conditon)!="salvage" : ~2200

# %%
df[~idx_drop].groupby([col, "condition"]).size().unstack().fillna(0)
# Out:
# condition     excellent    fair      good  like new    new  salvage
# title_status
# clean           82535.0  5628.0  114080.0   18027.0  655.0    179.0
# lien              580.0    41.0     377.0     260.0   23.0      3.0
# missing            36.0   159.0     169.0       7.0    2.0     33.0
# parts only          9.0    22.0      23.0       7.0    0.0     28.0
# rebuilt          2761.0   134.0    1326.0     764.0   29.0     21.0
# salvage           854.0   200.0     869.0     224.0   15.0    241.0

# %% [markdown]
# ### 14. transmission

# %%
col = "transmission"
df[col].value_counts()
# Out:
# automatic    336524
# other         62682
# manual        25118
# Name: transmission, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.boxplot(data=df[~idx_drop], y='price', x=col, ax=ax)
plt.show()

# %% [markdown]
# ### 15. VIN

# %% [markdown]
# VIN (Vehicle Identifier Number)

# %% [markdown]
# https://driving-tests.org/vin-decoder/

# %%
col = "VIN"
df[col].notnull().sum(), df[col].nunique()
# Out:
# (265838, 118264)

# %%
df[col].value_counts()
# Out:
# 1FMJU1JT1HEA52352    261
# 3C6JR6DT3KG560649    235
# 1FTER1EH1LLA36301    231
# 5TFTX4CN3EX042751    227
# 1GCHTCE37G1186784    214
#                     ...
# 2G4GP5EX5E9213578      1
# 1GCEK19J78Z219711      1
# JA4AT3AW1AZ006543      1
# 4T1BF28B61U153724      1
# SAJGX2749VCOO8376      1
# Name: VIN, Length: 118264, dtype: int64

# %% [markdown]
# * VIN - common (manufacturer, model, cylinders, fuel, title_status, tansmission, drive, type, paint_color)

# %% [markdown]
# (manufacture)-(model) : (dodge)-(ram)

# %%
col_check = "manufacturer"

df_grp = df.groupby(col)[col_check].nunique()
idx_dup_vin = df_grp[df_grp>1].index
df[df[col].isin(idx_dup_vin)].groupby(col)[col_check].agg(set)
# Out:
# VIN
# 00000000000000000                       {chevrolet, toyota}
# 11111111111111111        {mazda, chevrolet, honda, mercury}
# 1234567                                {chevrolet, pontiac}
# 19UUA66267A021807                            {ford, toyota}
# 19UUA66285A010806                            {acura, lexus}
# 1C6RD7GP5CS102305                              {ram, dodge}
# 1C6RR7FG0DS697066                              {ram, dodge}
# 1FADP3K2XFL258102                          {ford, chrysler}
# 1FDWE37L1WHA11298                         {ford, chevrolet}
# 1FTEW1EP5HFA09219                               {ford, ram}
# 1FTNE24L89DA76367                              {ford, audi}
# 1G1PD5SBXE7475984                       {chevrolet, subaru}
# 1G2AL18F487135452                      {chevrolet, pontiac}
# 1GKEL19W7XB500718                          {chevrolet, gmc}
# 1GKKVTED3CJ322495                               {ford, gmc}
# 1GNLVEED8AS137045                  {ford, chevrolet, dodge}
# 1GTHC24U05E194431                          {chevrolet, gmc}
# 1N4AL3AP8GC111239                        {chrysler, nissan}
# 1NXBU40E99Z063096                           {buick, toyota}
# 1VWBT7A30FC092572                       {volkswagen, honda}
# 1ZVBP8AM8E5221180                            {ford, toyota}
# 2D4GV77387S671809    {buick, chevrolet, ford, honda, dodge}
# 2HKRW2H87HH666833                        {chevrolet, honda}
# 3HGGK5G59HM700505                           {nissan, honda}
# 3N63M0ZN4FK710243                         {chevrolet, mini}
# 4A3AL25F48E004021                    {mitsubishi, chrysler}
# 5FNRL5H68BB024748                             {mini, honda}
# 5NPE24AA6GH427842                  {hyundai, mercedes-benz}
# 5TDZK22C77S053189                           {toyota, lexus}
# 99999999                                   {chevrolet, gmc}
# AFFORDABLEQUALITY                 {hyundai, chevrolet, bmw}
# JM1BL1SFXA1196709                             {mazda, jeep}
# NOTAVAILABLE12345              {chevrolet, buick, chrysler}
# SALJY1244VA728045                       {land rover, rover}
# YV4952CZ6D1669160                         {volvo, cadillac}
# Name: manufacturer, dtype: object

# %%
col_check = "model"

df_grp = df.groupby(col)[col_check].nunique()
idx_dup_vin = df_grp[df_grp>1].index
df[df[col].isin(idx_dup_vin)].groupby(col)[col_check].agg(set)
# Out:
# VIN
# 00000000000000000    {nan, corvette stingray, highlander limited}
# 00000000000238554       {xv crosstrek 2.0i limited, xv crosstrek}
# 00000000000594793                 {sierra 2500 hd, sierra 2500hd}
# 11111111111111111            {nan, acty, b2300, silverado 2500hd}
# 124379N592337                                     {camaro, rs/ss}
#                                          ...
# ZAM57RTA1E1094669              {Maserati Ghibli, MASERATI GHIBLI}
# ZAMBB18A720006592              {maserati sypder, maserati spyder}
# ZBBBS00AXD7149578                          {/ bertone x1/9, x1/9}
# ZFBCFXBT6GP386424                               {500x easy, 500x}
# ZFBERFAT9F6A76965      {promaster city, promaster city cargo van}
# Name: model, Length: 2381, dtype: object

# %% [markdown]
# [Sample with equal VIN]

# %%
df[df[col]=='1C6RD7GP5CS102305']
# Out:
#                 id                                                url  \
# 146848  7316922983  https://stlouis.craigslist.org/ctd/d/nixa-2012...
# 164185  7316922565  https://kansascity.craigslist.org/ctd/d/nixa-2...
# 221474  7316922427  https://springfield.craigslist.org/ctd/d/nixa-...
#
#                  region                          region_url  price    year  \
# 146848     st louis, MO      https://stlouis.craigslist.org  18988  2012.0
# 164185  kansas city, MO   https://kansascity.craigslist.org  18988  2012.0
# 221474      springfield  https://springfield.craigslist.org  18988  2012.0
#
#        manufacturer    model  condition    cylinders fuel  odometer  \
# 146848        dodge  ram1500  excellent  8 cylinders  gas  100348.0
# 164185          ram     1500  excellent  8 cylinders  gas  100348.0
# 221474          ram     1500  excellent  8 cylinders  gas  100348.0
#
#        title_status transmission                VIN drive       size   type  \
# 146848        clean    automatic  1C6RD7GP5CS102305   4wd  full-size  truck
# 164185        clean    automatic  1C6RD7GP5CS102305   4wd  full-size  truck
# 221474        clean    automatic  1C6RD7GP5CS102305   4wd  full-size  truck
#
#        paint_color                                          image_url  \
# 146848      silver  https://images.craigslist.org/00y0y_9rCFfAEnN4...
# 164185      silver  https://images.craigslist.org/00y0y_9rCFfAEnN4...
# 221474      silver  https://images.craigslist.org/00y0y_9rCFfAEnN4...
#
#                                               description  county state  \
# 146848  We are selling our CLEAN, 3 OWNER, ACCIDENT FR...     NaN    il
# 164185  We are selling our CLEAN, 3 OWNER, ACCIDENT FR...     NaN    ks
# 221474  We are selling our CLEAN, 3 OWNER, ACCIDENT FR...     NaN    mo
#
#               lat       long              posting_date region_url_parse
# 146848  37.047741 -93.303214  2021-05-04T15:27:59-0500          stlouis
# 164185  37.047741 -93.303214  2021-05-04T15:27:14-0500       kansascity
# 221474  37.047741 -93.303214  2021-05-04T15:27:00-0500      springfield

# %% [markdown]
# * 동일 차량이 여러 지역 사이트에 업로드되는 것으로 보임

# %%
df[df[col]=='JM1BL1SFXA1196709']
# Out:
#              id                                                url  \
# 779  7311421846  https://bham.craigslist.org/ctd/d/siluria-2010...
# 780  7311417807  https://bham.craigslist.org/ctd/d/siluria-2008...
#
#          region                   region_url  price    year manufacturer  \
# 779  birmingham  https://bham.craigslist.org   6900  2010.0        mazda
# 780  birmingham  https://bham.craigslist.org   8500  2008.0         jeep
#
#                model condition    cylinders fuel  odometer title_status  \
# 779               3i      good  4 cylinders  gas  165255.0      rebuilt
# 780  commander sport      good  8 cylinders  gas  198000.0        clean
#
#     transmission                VIN drive       size   type paint_color  \
# 779    automatic  JM1BL1SFXA1196709   fwd   mid-size  sedan        grey
# 780    automatic  JM1BL1SFXA1196709   rwd  full-size    SUV       black
#
#                                              image_url  \
# 779  https://images.craigslist.org/00N0N_4i4abv0MuR...
# 780  https://images.craigslist.org/00q0q_a9Uw5jHRe4...
#
#                                            description  county state  \
# 779  2010 Mazda 3i ; Automatic ; 2.0L Engine ; 4 Cy...     NaN    al
# 780  2008 Jeep Commander Sport ; Automatic ; 4.7L E...     NaN    al
#
#            lat       long              posting_date region_url_parse
# 779  33.243013 -86.817420  2021-04-23T12:00:32-0500             bham
# 780  33.243031 -86.817398  2021-04-23T11:54:12-0500             bham

# %%
df[df[col]=='3N63M0ZN4FK710243']
# Out:
#                 id                                                url  \
# 182486  7310504510  https://baltimore.craigslist.org/ctd/d/chesape...
# 233826  7310482208  https://charlotte.craigslist.org/ctd/d/chesape...
# 242338  7310479894  https://raleigh.craigslist.org/ctd/d/chesapeak...
# 394269  7310477461  https://norfolk.craigslist.org/ctd/d/chesapeak...
#
#                          region                        region_url  price  \
# 182486                baltimore  https://baltimore.craigslist.org  17366
# 233826                charlotte  https://charlotte.craigslist.org  17366
# 242338    raleigh / durham / CH    https://raleigh.craigslist.org  17366
# 394269  norfolk / hampton roads    https://norfolk.craigslist.org  17366
#
#           year manufacturer                  model  condition    cylinders  \
# 182486  2015.0         mini                  cargo  excellent  4 cylinders
# 233826  2015.0         mini                  cargo  excellent  4 cylinders
# 242338  2015.0         mini                  cargo  excellent  4 cylinders
# 394269  2015.0    chevrolet  city express lt cargo  excellent  4 cylinders
#
#        fuel  odometer title_status transmission                VIN drive  \
# 182486  gas   25445.0        clean    automatic  3N63M0ZN4FK710243   fwd
# 233826  gas   25445.0        clean    automatic  3N63M0ZN4FK710243   fwd
# 242338  gas   25445.0        clean    automatic  3N63M0ZN4FK710243   fwd
# 394269  gas   25445.0        clean    automatic  3N63M0ZN4FK710243   fwd
#
#                size      type paint_color  \
# 182486  sub-compact  mini-van       black
# 233826  sub-compact  mini-van       black
# 242338  sub-compact  mini-van       black
# 394269  sub-compact  mini-van       black
#
#                                                 image_url  \
# 182486  https://images.craigslist.org/00V0V_hVgIjBJFEF...
# 233826  https://images.craigslist.org/00V0V_hVgIjBJFEF...
# 242338  https://images.craigslist.org/00V0V_hVgIjBJFEF...
# 394269  https://images.craigslist.org/00V0V_hVgIjBJFEF...
#
#                                               description  county state  \
# 182486  2015 Chevrolet City Express LT Cargo Van, 2.0L...     NaN    md
# 233826  2015 Chevrolet City Express LT Cargo Van, 2.0L...     NaN    nc
# 242338  2015 Chevrolet City Express LT Cargo Van, 2.0L...     NaN    nc
# 394269  2015 Chevrolet City Express LT Cargo Van, 2.0L...     NaN    va
#
#              lat       long              posting_date region_url_parse
# 182486  36.64340 -76.242000  2021-04-21T15:42:43-0400        baltimore
# 233826  36.64340 -76.242000  2021-04-21T15:06:31-0400        charlotte
# 242338  36.64340 -76.242000  2021-04-21T15:02:58-0400          raleigh
# 394269  36.68829 -76.230521  2021-04-21T14:58:56-0400          norfolk

# %%
# outliers
df[df[col].apply(lambda x: str(x).isdigit())].groupby([col]).size().sort_values()
# Out:
# VIN
# 000                   1
# 14385554              1
# 1422360347            1
# 1412590               1
# 1402668737            1
#                      ..
# 00000000000000000    19
# 11111111111111111    24
# 14141414141414141    52
# 15151515151515151    81
# 13131313131313131    85
# Length: 339, dtype: int64

# %% [markdown]
# ### 16. drive

# %%
col = "drive"
df[col].value_counts()
# Out:
# 4wd    131904
# fwd    105517
# rwd     58892
# Name: drive, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.boxplot(data=df[~idx_drop], y='price', x=col, ax=ax)
plt.show()

# %%
df.groupby(["type", col])["price"].mean().unstack()
# Out:
# drive                  4wd           fwd            rwd
# type
# SUV           16356.015992  14010.735288   13961.529396
# bus           15563.000000   7500.352941   15825.709343
# convertible   24776.536264  11037.883871   21749.748236
# coupe         24846.736626   9704.832902   25361.472434
# hatchback     14186.390883  12335.831994   15410.701087
# mini-van       9598.367816   9244.002090   12811.764331
# offroad       16105.071942   7722.727273   11280.416667
# other         28712.221501  22875.297423   26422.019057
# pickup       172617.262180  87040.696560  242153.605247
# sedan         14615.308664  15412.610242   18332.783444
# truck         34306.778559  11517.420833   18297.484262
# van           18675.975862  15535.474695   18931.610807
# wagon         12716.550496  12251.330242   12050.490506

# %% [markdown]
# ### 17. size

# %%
col = "size"
df[col].value_counts()
# Out:
# full-size      63465
# mid-size       34476
# compact        19384
# sub-compact     3194
# Name: size, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.boxplot(data=df[~idx_drop], y='price', x=col, ax=ax)
plt.show()

# %%
ord_lbs = ["full-size", "mid-size", "compact", "sub-compact"]
df[~idx_drop].groupby(["type", col])["price"].median().unstack()[ord_lbs].sort_values(["full-size"]).applymap("{:.0f}".format)
# Out:
# size        full-size mid-size compact sub-compact
# type
# mini-van         5995     6000    7000       17366
# wagon            7425     8248   11633        4000
# bus              7500    11650    4000       15000
# hatchback        7500     7900    6995        7000
# sedan            7500     7900    7999        6995
# other           10995     8000   50130        5495
# SUV             11500    11968   12998        7845
# coupe           12999    11975    8750       14500
# van             13997    14250   12997        8900
# offroad         14900    14800    9500        9995
# convertible     15000    11500    9500       12989
# pickup          17950     8975   22314        9388
# truck           22988    14950   10999        6500

# %% [markdown]
# ### 18. type

# %%
col = "type"
df[col].value_counts()
# Out:
# sedan          87056
# SUV            77284
# pickup         43510
# truck          35279
# other          22110
# coupe          19204
# hatchback      16598
# wagon          10751
# van             8548
# convertible     7731
# mini-van        4825
# offroad          609
# bus              517
# Name: type, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,4))
lbs = df.groupby([col])["price"].mean().sort_values(ascending=False).index
sns.boxplot(data=df[~idx_drop], y='price', x=col, order=lbs, ax=ax)
ax.set_xticklabels(lbs, rotation=45)
plt.show()

# %% [markdown]
# ### 19. paint_color

# %%
col = "paint_color"
df[col].value_counts()
# Out:
# white     79285
# black     62861
# silver    42970
# blue      31223
# red       30473
# grey      24416
# green      7343
# custom     6700
# brown      6593
# yellow     2142
# orange     1984
# purple      687
# Name: paint_color, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,4))
lbs = df.groupby([col])["price"].mean().sort_values(ascending=False).index
sns.boxplot(data=df[~idx_drop], y='price', x=col, order=lbs, ax=ax)
ax.set_xticklabels(lbs, rotation=45)
plt.show()

# %% [markdown]
# ### 20. image_url

# %% [markdown]
# * drop

# %%
cols_drop.append("image_url")

# %%
col = "image_url"
df.shape[0], df[col].nunique(), df[col].isnull().sum()
# Out:
# (426880, 241899, 68)

# %% [markdown]
# ### 21. description

# %% [markdown]
# * drop

# %%
cols_drop.append("description")

# %%
col = "description"
df[col].sample(10)
# Out:
# 255778    I am selling my camry because I have purchased...
# 367715    SOLD!!!   This Ford Explorer has just been Sol...
# 320292    Carz Planet          STOCK #:  6999    💲 💲 FOR...
# 158924    2013  JEEP WRANGLER Oscar Mike Sport Utility  ...
# 36798     2018 RAM 1500 Laramie EcoDiesel Crew Cab 1-Own...
# 185775    2016 Chevrolet Chevy Silverado 1500 LS Crew Ca...
# 308912    Check Out This Totally Awesome 2016 Mitsubishi...
# 56838     2019 Ram 2500 Power Wagon 4WD 4D Crew Cab  8 c...
# 360241    2021 *GMC* *Sierra 1500* 21 GMC SIERRA 1500, A...
# 272771    2014 Chevrolet Chevy Corvette Stingray 2dr Z51...
# Name: description, dtype: object

# %% [markdown]
# ### 22. county

# %% [markdown]
# * drop

# %%
cols_drop.append("county")

# %% [markdown]
# ### 23. state

# %%
col = "state"
df[col].nunique()
# Out:
# 51

# %%
df[col].value_counts().head(10)
# Out:
# ca    50614
# fl    28511
# tx    22945
# ny    19386
# oh    17696
# or    17104
# mi    16900
# nc    15277
# wa    13861
# pa    13753
# Name: state, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(16,4))
lbs = df.groupby([col])["price"].mean().sort_values(ascending=False).index
sns.boxplot(data=df[~idx_drop], y='price', x=col, order=lbs, ax=ax)
ax.set_xticklabels(lbs, rotation=90)
plt.show()

# %% [markdown]
# ### 24. lat & long

# %% [markdown]
# * drop

# %%
cols_drop.extend(["lat", "long"])

# %% [markdown]
# ### 25. posting_date

# %%
col = "posting_date"
df[col] = pd.to_datetime(df[col], utc=True).dt.date
df[col]
# Out:
# 0                NaT
# 1                NaT
# 2                NaT
# 3                NaT
# 4                NaT
#              ...
# 426875    2021-04-04
# 426876    2021-04-04
# 426877    2021-04-04
# 426878    2021-04-04
# 426879    2021-04-04
# Name: posting_date, Length: 426880, dtype: object

# %%
df["posting_year"] = pd.to_datetime(df[col]).dt.year # 현재는 단일값으로 학습에는 활용하지 않음
df["posting_day"] = pd.to_datetime(df[col]).dt.dayofyear

df[["posting_date", "posting_year", "posting_day"]].sample(10)
# Out:
#        posting_date  posting_year  posting_day
# 376722   2021-04-29        2021.0        119.0
# 305567   2021-04-26        2021.0        116.0
# 233683   2021-04-22        2021.0        112.0
# 133198   2021-04-26        2021.0        116.0
# 166942   2021-04-23        2021.0        113.0
# 73292    2021-04-27        2021.0        117.0
# 350140   2021-04-08        2021.0         98.0
# 157802   2021-04-21        2021.0        111.0
# 326096   2021-04-27        2021.0        117.0
# 39317    2021-04-13        2021.0        103.0

# %%
cols_drop
# Out:
# ['url',
#  'region_url',
#  'region_url_parse',
#  'image_url',
#  'description',
#  'county',
#  'lat',
#  'long']
